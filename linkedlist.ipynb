# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        address = Node(data)
        address.next = self.head
        self.head = address
    def display(self):
        current = self.head
        while current:
            print(current.data)
            current = current.next    
l = linkedlist()
l.insert(1)
l.insert(2)
l.insert(3)
l.display()
# Out:
# 3
# 2
# 1

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def insert(self, data):
        new_node = Node(data)
        print("new:",new_node)
        if self.head is None:
            self.head = new_node
            print(self.head)
        else:
            current = self.head
            print("1:",self.head)
            while current.next:
                print("2:",current.next)
                current = current.next
                print("inner:",current)
            print("current 1:",current.next)
            current.next = new_node
            print("current 2:",current.next)
    def display(self):
        current = self.head
        print(self.head)
        while current:
            print(current.data)
            current = current.next
l = linkedlist()
l.insert(1)
l.insert(2)
l.insert(3)
l.display()
# Out:
# new: <__main__.Node object at 0x000001FE683C1810>
# ...
# new: <__main__.Node object at 0x000001FE67FC0AD0>
# 1: <__main__.Node object at 0x000001FE683C1810>
# current 1: None
# current 2: <__main__.Node object at 0x000001FE67FC0AD0>
# new: <__main__.Node object at 0x000001FE683CBE90>
# 1: <__main__.Node object at 0x000001FE683C1810>
# 2: <__main__.Node object at 0x000001FE67FC0AD0>
# inner: <__main__.Node object at 0x000001FE67FC0AD0>
# current 1: None
# current 2: <__main__.Node object at 0x000001FE683CBE90>
# ...
# 1
# 2
# 3

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        address = Node(data)
        if self.head is None:
            self.head = address
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = address
    def display(self):
         current = self.head
         while current:
             print(current.data)
             current = current.next
l = linkedlist()
l.insert(1)
l.insert(2)
l.insert(3)
l.display()
# Out:
# 1
# 2
# 3

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        address = Node(data)
        address.next = self.head
        self.head = address
    def display(self):
        current = self.head
        while current:
            print(current.data)
            current = current.next
l = linkedlist()
l.insert(1)
l.insert(2)
l.insert(3)
l.display()
# Out:
# 3
# 2
# 1

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        address = Node(data)
        if self.head is None:
            self.head = address
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = address
            
    def display(self):
         current = self.head
         while current:
             print(current.data)
             current = current.next         
l = linkedlist()
l.insert(1)
l.insert(2)
l.insert(3)
l.insert(4)
l.delete(3)
# Out:
# 1
# 2
# 3
# 4

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert(self, data):
        node = Node(data)
        if self.head is None:
            self.head = node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = node  # fixed typo here

    def display(self):
        current = self.head
        while current:
            print(current.data)
            current = current.next

# Test the LinkedList
l = LinkedList()
l.insert(1)
l.insert(2)
l.insert(3)
l.insert(4)
l.display()
# Out:
# 1
# 2
# 3
# 4

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        node = Node(data)
        if self.head is None:
            self.head = node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = node 
    def delete(self,val):
        current = self.head
        while current:
            value = current.data
            if value == val:
                current.next = current.next
            else:
                current = current.next
    def display(self):
        current = self.head
        while current:
            print(current.data)
            current = current.next
        current = node    
            
l = linkedlist()
l.insert(1)
l.insert(2)
l.insert(3)
l.insert(4)
l.delete(3)
l.display()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 37
#      35 l.insert(3)
#      36 l.insert(4)
# ---> 37 l.delete(3)
#      38 l.display()
#
# Cell In[3], line 19, in linkedlist.delete(self, val)
#      17 def delete(self,val):
#      18     current = self.head
# ---> 19     while current:
#      20         value = current.data
#      21         if value == val:
#
# KeyboardInterrupt:

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class linkedlist:
    def __init__(self):
        self.head = None

    def insert(self, data):
        node = Node(data)
        if self.head is None:
            self.head = node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = node 

    def delete(self, val):
        current = self.head
        prev = None
        while current:
            if current.data == val:
                if prev is None:
                    self.head = current.next
                else:
                    prev.next = current.next
                return
            prev = current
            current = current.next

    def display(self):
        current = self.head
        while current:
            print(current.data)
            current = current.next

l = linkedlist()
l.insert(3)
l.insert(2)
l.insert(3)
l.insert(4)
l.delete(3)
l.display()
# Out:
# 2
# 3
# 4

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        node = Node(data)
        if self.head is None:
            self.head = node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = node 
    def display(self):
        current = self.head
        while current:
            print(current.data)
            current = current.next
    def insert_at_beg(self,data):
        node = Node(data)
        node.next = self.head
        current = node
        while current:
            print(current.data)
            current = current.next
    def insert_at_end(self,data):
        current = self.head
        node = Node(data)
        while current:
            temp = current
            print(current.data)
            current = current.next
        temp.next = node
        print(node.data)
    def insert_at_pos(self,data,pos):
        node = Node(data)
        curr = self.head
        n = 0
        while curr:
            if pos-1 == n:
                temp = curr.next
                curr.next = node
                node.next = temp
                curr = temp
            else:
                curr = curr.next
                n += 1
        print(n)
    def display_insert(self):
        curr = self.head
        while curr:
            print(curr.data)
            curr = curr.next
                
            
l = linkedlist()
l.insert(1)
l.insert(2)
l.insert(4)
l.insert(5)
l.insert_at_pos(3,2)
# Out:
# 1

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        node = Node(data)
        if self.head is None:
            self.head = node
        else:
            curr = self.head
            while curr.next:
                curr = curr.next
            curr.next = node
    def display(self):
        curr = self.head
        while curr:
            print(curr.data)
            curr = curr.next
    def delete(self,data):
        curr = self.head
        if curr.data == data:
            self.head = curr.next
        while curr:
            new = curr.next
            if new:
                if new.data == data:
                    new = new.next
                    curr.next = new
            curr = curr.next    
    def display(self):
        curr = self.head
        while curr:
            print(curr.data)
            curr = curr.next        
l = linkedlist()
l.insert(1)
l.insert(2)
l.insert(3)
l.insert(4)
l.insert(5)
l.insert(6)
l.delete(1)
l.display()
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

    def append(self, val):
        new_node = Node(val)
        if self.head is None:
            self.head = new_node
            return
        curr = self.head
        while curr.next:
            curr = curr.next
        curr.next = new_node
        new_node.prev = curr

    def print_forward(self):
        curr = self.head
        while curr:
            print(curr.val, end=" <-> ")
            curr = curr.next
        print("None")

    def print_backward(self):
        curr = self.head
        if not curr:
            return
        while curr.next:
            curr = curr.next  # go to last node
        while curr:
            print(curr.val, end=" <-> ")
            curr = curr.prev
        print("None")

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

    def insert(self, data):
        node = Node(data)
        if self.head is None:
            self.head = node
        else:
            curr = self.head
            while curr.next:
                curr = curr.next  # Fix: `cuur` -> `curr`
            curr.next = node
            node.prev = curr

    def display_for_next(self):
        curr = self.head
        while curr:
            print(curr.data,"->",end="")
            curr = curr.next
    def display(self):
        
# Create list and insert elements
l = DoublyLinkedList()  # Fix: class name was wrongly called as 'linkedlist'
l.insert(1)
l.insert(2)
l.insert(3)
l.display()
# Out:
# 1 ->2 ->3 ->

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None
class doublylinkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        node = Node(data)
        if self.head is None:
            self.head = node
        else:
            curr = self.head
            while curr.next:
                curr = curr.next
            curr.next = node
            node.prev = curr
    def display_backward(self):
        curr = self.head
        while curr.next:
            curr = curr.next
        while curr:
            print(curr.data)
            curr = curr.prev
    def display_forward(self):
        curr = self.head
        while curr:
            print(curr.data)
            curr = curr.next
            
l = doublylinkedlist()
l.insert(1)
l.insert(2)
l.insert(3)
l.insert(4)
l.display_forward()
# Out:
# 4
# 3
# 2
# 1

# %%
class Node:
    def __init__(self,data):
        self.data =data
        self.prev = None
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def insert(self,data):
        node = Node(data)
        if self.head is None:
            self.head = node
        else:
            curr = self.head
            while curr.next:
                curr = curr.next
            curr.next = node
            node.prev = curr
    def display_fo_back(self):
        curr = self.head
        print("Forward")
        while curr:
            print(curr.data,"->",end = "")
            curr = curr.next
        print()
        print("backward")
        temp = self.head
        while temp.next:
            temp = temp.next
        while temp:
            print(temp.data,"<->",end = "")
            temp = temp.prev
    def insert_at_beginng(self,data):
         node = Node(data)
         node.next = self.head
         self.head = node
         curr = self.head
         while curr:
             print(curr.data)
             curr = curr.next
    def insert_at_end(self,data):
        node = Node(data)
        curr = self.head
        while curr.next:
            curr = curr.next
        curr.next = node    
        temp = self.head
        while temp:
            print(temp.data)
            temp = temp.next
    def delete_head(self):
        print("forward")
        curr = self.head
        self.head = curr.next
        self.head.prev = None
        curr = self.head
        while curr:
            print(curr.data)
            curr = curr.next
        curr = self.head
        print("backward")
        while curr.next:
            curr = curr.next
        while curr:
            print(curr.data)
            curr = curr.prev
    def delete_tail(self):
         print("forward tail")
         curr = self.head
         while curr.next:
             curr = curr.next
         prev = curr.prev
         prev.next = None
         curr = self.head
         while curr:
             print(curr.data)
             curr = curr.next
         curr = self.head
         print("backward tail")
         while curr.next:
             curr = curr.next
         while curr:
             print(curr.data)
             curr = curr.prev
           
            
l = linkedlist()
l.insert(1)
l.insert(2)
l.insert(3)
l.insert(4)
l.delete_tail()
# Out:
# forward tail
# 1
# 2
# 3
# backward tail
# 3
# 2
# 1
